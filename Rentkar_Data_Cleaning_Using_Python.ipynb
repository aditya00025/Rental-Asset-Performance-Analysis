# %% [markdown]
# #Data Cleaning and Preprocessing

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2bd8b73d-adf0-4079-b725-e23014cef421" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bd8b73d-adf0-4079-b725-e23014cef421">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("Mock_Asset_Data_-_Rentkar__Updated_Asset_Types_.csv" , encoding='latin-1')

# %%
df.head()
# Out:
#   Asset ID Asset Type Vendor Name  Monthly Rent  Asset Purchase Cost  \
# 0  AST0001     Guitar     VendorA          1915                15486
# 1  AST0002      Gopro     VendorB          1633                18335
# 2  AST0003      Gopro     VendorA          2623                31364
# 3  AST0004      Gopro     VendorB          3574                47259
# 4  AST0005     Laptop     VendorB          2782                33576
#
#   Date of Acquisition Assigned Employee ID Current Status  \
# 0          2022-04-16               EMP893         Active
# 1          2023-07-17               EMP887      In Repair
# 2          2022-03-22               EMP162         Active
# 3          2022-05-13               EMP598         Active
# 4          2022-05-18               EMP645         Active
#
#    Usage Days (last 30)    City  Monthly Revenue per Asset
# 0                     1  Jaipur                       1588
# 1                     2   Delhi                       3012
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Asset ID                   200 non-null    object
#  1   Asset Type                 200 non-null    object
#  2   Vendor Name                200 non-null    object
#  3   Monthly Rent               200 non-null    int64
#  4   Asset Purchase Cost        200 non-null    int64
#  5   Date of Acquisition        200 non-null    object
#  6   Assigned Employee ID       200 non-null    object
#  7   Current Status             200 non-null    object
#  8   Usage Days (last 30)       200 non-null    int64
#  9   City                       200 non-null    object
#  10  Monthly Revenue per Asset  200 non-null    int64
# dtypes: int64(4), object(7)
# memory usage: 17.3+ KB

# %%
df.isnull().sum()
# Out:
# Asset ID                     0
# Asset Type                   0
# Vendor Name                  0
# Monthly Rent                 0
# Asset Purchase Cost          0
# Date of Acquisition          0
# Assigned Employee ID         0
# Current Status               0
# Usage Days (last 30)         0
# City                         0
# Monthly Revenue per Asset    0
# dtype: int64

# %%
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
df['Date of Acquisition	'] = pd.to_datetime(df['Date of Acquisition'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Asset ID                   200 non-null    object
#  1   Asset Type                 200 non-null    object
#  2   Vendor Name                200 non-null    object
#  3   Monthly Rent               200 non-null    int64
#  4   Asset Purchase Cost        200 non-null    int64
#  5   Date of Acquisition        200 non-null    object
#  6   Assigned Employee ID       200 non-null    object
#  7   Current Status             200 non-null    object
#  8   Usage Days (last 30)       200 non-null    int64
#  9   City                       200 non-null    object
#  10  Monthly Revenue per Asset  200 non-null    int64
#  11  Date of Acquisition	       200 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 18.9+ KB

# %%
df[['Monthly Rent','Asset Purchase Cost','Usage Days (last 30)', 'Monthly Revenue per Asset']].describe()
# Out:
#        Monthly Rent  Asset Purchase Cost  Usage Days (last 30)  \
# count    200.000000           200.000000            200.000000
# mean    2431.855000         30954.685000             14.590000
# std      931.252101         11464.089416              8.627518
# min      804.000000         10009.000000              0.000000
# 25%     1646.750000         20996.000000              7.000000
# 50%     2433.000000         31710.500000             15.500000
# 75%     3291.250000         39586.750000             22.000000
# max     3971.000000         49764.000000             30.000000
#
#        Monthly Revenue per Asset
# count                 200.000000
# mean                 3296.650000
# std                  1458.114097
# min                  1001.000000
# 25%                  1917.000000
# 50%                  3169.000000
# 75%                  4535.750000
# max                  5969.000000

# %%
df.groupby('Asset Type')[['Monthly Revenue per Asset']].sum().rename(columns={'Monthly Revenue per Asset': 'Sum of Monthly Revenue per Asset'}).sort_values(by='Sum of Monthly Revenue per Asset', ascending=False)
# Out:
#             Sum of Monthly Revenue per Asset
# Asset Type
# Gopro                                 144481
# Gaming PC                             141397
# Guitar                                136611
# PS5                                   127544
# Laptop                                109297
